# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
from torch.utils.data import DataLoader

# %%
mean = [0.5071, 0.4867, 0.4408]
std  = [0.2675, 0.2565, 0.2761]

transform = transforms.Compose([
  
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

# %%
train_data = datasets.CIFAR100(root='./data', train=True, download=False, transform=transform)
test_data = datasets.CIFAR100(root='./data', train=False, download=False, transform=transform)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %%
class DenseLayer(nn.Module):
    def __init__(self, in_channels, growth_rate):
        super(DenseLayer, self).__init__()
        self.layer = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, growth_rate, kernel_size=3, padding=1, bias=False)
        )

    def forward(self, x):
        out = self.layer(x)
        return torch.cat([x, out], dim=1)  # Concatenate input and output

# %%
class TwoLayerDenseBlock(nn.Module):
    def __init__(self, in_channels, growth_rate, use_dropout=False):
        super(TwoLayerDenseBlock, self).__init__()
        self.layer1 = DenseLayer(in_channels, growth_rate)
        self.layer2 = DenseLayer(in_channels + growth_rate, growth_rate)  # concat adds channels

        total_channels = in_channels + 2 * growth_rate
        self.post = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        if use_dropout:
            self.post.add_module("dropout", nn.Dropout(p=0.2))

        self.out_channels = total_channels  # helpful for tracking channels later

    def forward(self, x):
        x = self.layer1(x)
        x = self.layer2(x)
        return self.post(x)

# %%
class DenseNet(nn.Module):
    def __init__(self, num_classes=100):
        super(DenseNet, self).__init__()
        growth = 32
        self.block1 = TwoLayerDenseBlock(3, growth)
        self.block2 = TwoLayerDenseBlock(self.block1.out_channels, growth)
        self.block3 = TwoLayerDenseBlock(self.block2.out_channels, growth, use_dropout=True)
        self.block4 = TwoLayerDenseBlock(self.block3.out_channels, growth, use_dropout=True)

        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(self.block4.out_channels, num_classes)
        )

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.classifier(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = DenseNet(num_classes=100).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, weight_decay=5e-4, momentum=0.9)

# %%
epochs = 100

for epoch in range(epochs):
    # Training
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    train_accuracy = 100. * correct / total
    avg_train_loss = train_loss / len(train_loader)

    # Evaluation
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_loss += loss.item()
            _, predicted = outputs.max(1)
            val_total += labels.size(0)
            val_correct += predicted.eq(labels).sum().item()

    val_accuracy = 100. * val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)

    # Print epoch summary
    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.2f}%")
    print(f"Val   Loss: {avg_val_loss:.4f}, Val   Acc: {val_accuracy:.2f}%\n")
# Out:
# Epoch [1/100]
# Train Loss: 4.3586, Train Acc: 4.22%
# Val   Loss: 4.1549, Val   Acc: 8.23%
#
# Epoch [2/100]
# Train Loss: 3.9945, Train Acc: 9.45%
# Val   Loss: 3.8549, Val   Acc: 12.40%
#
# Epoch [3/100]
# Train Loss: 3.7204, Train Acc: 13.08%
# Val   Loss: 3.6294, Val   Acc: 15.80%
#
# Epoch [4/100]
# Train Loss: 3.5164, Train Acc: 16.19%
# Val   Loss: 3.4065, Val   Acc: 19.03%
#
# Epoch [5/100]
# Train Loss: 3.3486, Train Acc: 19.07%
# Val   Loss: 3.2871, Val   Acc: 20.74%
#
# Epoch [6/100]
# Train Loss: 3.1878, Train Acc: 21.66%
# Val   Loss: 3.1232, Val   Acc: 24.06%
#
# Epoch [7/100]
# Train Loss: 3.0485, Train Acc: 24.16%
# Val   Loss: 3.0496, Val   Acc: 24.49%
#
# Epoch [8/100]
# Train Loss: 2.9315, Train Acc: 26.27%
# Val   Loss: 2.9404, Val   Acc: 26.70%
#
# Epoch [9/100]
# Train Loss: 2.8317, Train Acc: 28.22%
# Val   Loss: 2.8892, Val   Acc: 27.58%
#
# Epoch [10/100]
# Train Loss: 2.7520, Train Acc: 29.76%
# Val   Loss: 2.7387, Val   Acc: 30.13%
#
# Epoch [11/100]
# Train Loss: 2.6775, Train Acc: 31.12%
# Val   Loss: 2.6510, Val   Acc: 31.38%
#
# Epoch [12/100]
# Train Loss: 2.6002, Train Acc: 32.79%
# Val   Loss: 2.6310, Val   Acc: 31.75%
#
# Epoch [13/100]
# Train Loss: 2.5344, Train Acc: 34.09%
# Val   Loss: 2.6174, Val   Acc: 33.14%
#
# Epoch [14/100]
# Train Loss: 2.4726, Train Acc: 35.56%
# Val   Loss: 2.4992, Val   Acc: 35.02%
#
# Epoch [15/100]
# Train Loss: 2.4232, Train Acc: 36.62%
# Val   Loss: 2.7702, Val   Acc: 31.50%
#
# Epoch [16/100]
# Train Loss: 2.3789, Train Acc: 37.37%
# Val   Loss: 2.4014, Val   Acc: 37.69%
#
# Epoch [17/100]
# Train Loss: 2.3280, Train Acc: 38.59%
# Val   Loss: 2.3480, Val   Acc: 38.89%
#
# Epoch [18/100]
# Train Loss: 2.2743, Train Acc: 39.52%
# Val   Loss: 2.4131, Val   Acc: 36.60%
#
# Epoch [19/100]
# Train Loss: 2.2333, Train Acc: 40.61%
# Val   Loss: 2.2554, Val   Acc: 41.05%
#
# Epoch [20/100]
# Train Loss: 2.1957, Train Acc: 41.37%
# Val   Loss: 2.2431, Val   Acc: 40.44%
#
# Epoch [21/100]
# Train Loss: 2.1554, Train Acc: 42.38%
# Val   Loss: 2.1577, Val   Acc: 42.15%
#
# Epoch [22/100]
# Train Loss: 2.1253, Train Acc: 43.05%
# Val   Loss: 2.2079, Val   Acc: 41.33%
#
# Epoch [23/100]
# Train Loss: 2.0892, Train Acc: 43.85%
# Val   Loss: 2.1572, Val   Acc: 42.67%
#
# Epoch [24/100]
# Train Loss: 2.0675, Train Acc: 44.48%
# Val   Loss: 2.1095, Val   Acc: 44.06%
#
# Epoch [25/100]
# Train Loss: 2.0341, Train Acc: 45.23%
# Val   Loss: 2.1597, Val   Acc: 42.94%
#
# Epoch [26/100]
# Train Loss: 2.0106, Train Acc: 45.74%
# Val   Loss: 2.2137, Val   Acc: 40.82%
#
# Epoch [27/100]
# Train Loss: 1.9730, Train Acc: 46.61%
# Val   Loss: 2.0156, Val   Acc: 45.50%
#
# Epoch [28/100]
# Train Loss: 1.9579, Train Acc: 46.72%
# Val   Loss: 2.1067, Val   Acc: 44.10%
#
# Epoch [29/100]
# Train Loss: 1.9358, Train Acc: 47.32%
# Val   Loss: 2.1356, Val   Acc: 43.49%
#
# Epoch [30/100]
# Train Loss: 1.9087, Train Acc: 48.15%
# Val   Loss: 1.9630, Val   Acc: 47.12%
#
# Epoch [31/100]
# Train Loss: 1.8896, Train Acc: 48.49%
# Val   Loss: 2.2347, Val   Acc: 41.97%
#
# Epoch [32/100]
# Train Loss: 1.8702, Train Acc: 49.06%
# Val   Loss: 1.9690, Val   Acc: 46.92%
#
# Epoch [33/100]
# Train Loss: 1.8535, Train Acc: 49.35%
# Val   Loss: 1.9594, Val   Acc: 47.39%
#
# Epoch [34/100]
# Train Loss: 1.8343, Train Acc: 49.88%
# Val   Loss: 1.8909, Val   Acc: 48.56%
#
# Epoch [35/100]
# Train Loss: 1.8190, Train Acc: 49.98%
# Val   Loss: 1.9082, Val   Acc: 48.76%
#
# Epoch [36/100]
# Train Loss: 1.8054, Train Acc: 50.40%
# Val   Loss: 1.8707, Val   Acc: 48.77%
#
# Epoch [37/100]
# Train Loss: 1.7874, Train Acc: 50.97%
# Val   Loss: 1.9123, Val   Acc: 48.16%
#
# Epoch [38/100]
# Train Loss: 1.7733, Train Acc: 51.27%
# Val   Loss: 1.8776, Val   Acc: 49.11%
#
# Epoch [39/100]
# Train Loss: 1.7591, Train Acc: 51.31%
# Val   Loss: 1.8128, Val   Acc: 50.59%
#
# Epoch [40/100]
# Train Loss: 1.7426, Train Acc: 51.78%
# Val   Loss: 1.8257, Val   Acc: 49.92%
#
# Epoch [41/100]
# Train Loss: 1.7322, Train Acc: 52.28%
# Val   Loss: 1.8751, Val   Acc: 49.17%
#
# Epoch [42/100]
# Train Loss: 1.7156, Train Acc: 52.36%
# Val   Loss: 1.7910, Val   Acc: 50.61%
#
# Epoch [43/100]
# Train Loss: 1.7054, Train Acc: 52.86%
# Val   Loss: 1.8459, Val   Acc: 49.93%
#
# Epoch [44/100]
# Train Loss: 1.6924, Train Acc: 53.03%
# Val   Loss: 1.8599, Val   Acc: 49.45%
#
# Epoch [45/100]
# Train Loss: 1.6809, Train Acc: 53.54%
# Val   Loss: 1.8703, Val   Acc: 48.51%
#
# Epoch [46/100]
# Train Loss: 1.6699, Train Acc: 53.54%
# Val   Loss: 1.7989, Val   Acc: 50.98%
#
# Epoch [47/100]
# Train Loss: 1.6689, Train Acc: 53.62%
# Val   Loss: 1.7621, Val   Acc: 51.79%
#
# Epoch [48/100]
# Train Loss: 1.6480, Train Acc: 54.34%
# Val   Loss: 1.7706, Val   Acc: 52.40%
#
# Epoch [49/100]
# Train Loss: 1.6389, Train Acc: 54.40%
# Val   Loss: 1.9075, Val   Acc: 49.31%
#
# Epoch [50/100]
# Train Loss: 1.6316, Train Acc: 54.44%
# Val   Loss: 1.7964, Val   Acc: 51.36%
#
# Epoch [51/100]
# Train Loss: 1.6245, Train Acc: 54.77%
# Val   Loss: 1.7656, Val   Acc: 52.05%
#
# Epoch [52/100]
# Train Loss: 1.6164, Train Acc: 55.12%
# Val   Loss: 1.7146, Val   Acc: 53.11%
#
# Epoch [53/100]
# Train Loss: 1.6056, Train Acc: 55.24%
# Val   Loss: 1.7844, Val   Acc: 51.55%
#
# Epoch [54/100]
# Train Loss: 1.5964, Train Acc: 55.43%
# Val   Loss: 1.7115, Val   Acc: 53.14%
#
# Epoch [55/100]
# Train Loss: 1.5858, Train Acc: 55.37%
# Val   Loss: 1.7398, Val   Acc: 52.81%
#
# Epoch [56/100]
# Train Loss: 1.5826, Train Acc: 55.63%
# Val   Loss: 1.7026, Val   Acc: 53.50%
#
# Epoch [57/100]
# Train Loss: 1.5740, Train Acc: 55.84%
# Val   Loss: 1.7380, Val   Acc: 52.62%
#
# Epoch [58/100]
# Train Loss: 1.5619, Train Acc: 56.18%
# Val   Loss: 1.6855, Val   Acc: 54.05%
#
# Epoch [59/100]
# Train Loss: 1.5632, Train Acc: 56.35%
# Val   Loss: 1.7509, Val   Acc: 52.62%
#
# Epoch [60/100]
# Train Loss: 1.5492, Train Acc: 56.51%
# Val   Loss: 1.7092, Val   Acc: 53.47%
#
# Epoch [61/100]
# Train Loss: 1.5413, Train Acc: 56.71%
# Val   Loss: 1.6940, Val   Acc: 54.12%
#
# Epoch [62/100]
# Train Loss: 1.5395, Train Acc: 56.75%
# Val   Loss: 1.7079, Val   Acc: 53.44%
#
# Epoch [63/100]
# Train Loss: 1.5328, Train Acc: 56.88%
# Val   Loss: 1.7223, Val   Acc: 52.39%
#
# Epoch [64/100]
# Train Loss: 1.5181, Train Acc: 57.04%
# Val   Loss: 1.6895, Val   Acc: 53.96%
#
# Epoch [65/100]
# Train Loss: 1.5163, Train Acc: 57.20%
# Val   Loss: 1.7090, Val   Acc: 53.66%
#
# Epoch [66/100]
# Train Loss: 1.5119, Train Acc: 57.23%
# Val   Loss: 1.7360, Val   Acc: 52.26%
#
# Epoch [67/100]
# Train Loss: 1.5048, Train Acc: 57.50%
# Val   Loss: 1.7132, Val   Acc: 53.29%
#
# Epoch [68/100]
# Train Loss: 1.5004, Train Acc: 57.61%
# Val   Loss: 1.6620, Val   Acc: 54.09%
#
# Epoch [69/100]
# Train Loss: 1.4937, Train Acc: 57.67%
# Val   Loss: 1.6012, Val   Acc: 55.83%
#
# Epoch [70/100]
# Train Loss: 1.4871, Train Acc: 57.87%
# Val   Loss: 1.6307, Val   Acc: 55.34%
#
# Epoch [71/100]
# Train Loss: 1.4806, Train Acc: 57.98%
# Val   Loss: 1.6521, Val   Acc: 55.05%
#
# Epoch [72/100]
# Train Loss: 1.4784, Train Acc: 58.20%
# Val   Loss: 1.6834, Val   Acc: 53.70%
